# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np
import csv

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  8
pc_qui = df_qui /  8

# %%
# 2) Seu código aqui
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
total/90
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
total_gt_45 = total[total['Qt_acertos'] > 45]
total_gt_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. 
# Monte um novo DataFrame com os alunos desqualificados por este critério.
df_eliminados = total[(df_mat['Qt_acertos'] == 0) |
                      (df_fis['Qt_acertos'] == 0) |
                      (df_qui['Qt_acertos'] == 0)]

df_eliminados
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31
# 20          53
# 25          27
# 26          40
# 27          50
# 33          39
# 35          48
# 49          19
# 56          39
# 65          24
# 66          31
# 72          50
# 73          37
# 74          39
# 84          26
# 89          63
# 92          40
# 94          25
# 98          40

# %%
# Quantos são esses alunos?
df_eliminados.count()
# Out:
# Qt_acertos    23
# dtype: int64

# %%
# Qual a média desses alunos em história e geografia?
#df_hist_geo_eliminados = total.loc[df_eliminados.index, ['df_his', 'df_geo']].mean(axis=1)

df_hist_geo = total
df_hist_geo['media_his'] = df_his['Qt_acertos']/8
df_hist_geo['media_geo'] = df_geo['Qt_acertos']/8
filtro_eliminado = df_hist_geo.index.isin(df_eliminados.index)
df_hist_geo_eliminados = df_hist_geo[filtro_eliminado]
df_hist_geo_eliminados.head()
# Out:
#     Qt_acertos  media_his  media_geo
# 3           32      0.000      0.375
# 6           29      0.625      0.875
# 10          31      0.125      0.375
# 12          42      0.125      0.375
# 14          31      0.125      0.125

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
pwd
# Out:
# 'C:\\Users\\Bill_\\Desktop\\Projetos\\EBAC\\DataScience\\Modolo 4'

# %%
df_teste = pd.read_csv('vac_ACRE.csv', sep=';')
df_teste
# Out:
#                                       document_id  \
# 0       b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1       a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2       af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3       4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4       000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
# ...                                           ...
# 169066  1d8f6ea9-d3f5-4882-9fe4-9d2f3ef88d77-i0b0
# 169067  77ff98a4-79fb-47c9-aafa-8bf45708c4bc-i0b0
# 169068  1da067bc-9989-4fa4-8838-e1e40cdfeebf-i0b0
# 169069  eacc22e0-6f78-460f-a8e7-d85c6129951e-i0b0
# 169070  02795bd0-b1a7-49c1-83ca-90a9f9b4b794-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1       f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2       6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# ...

# %%
#with open('C:\\Users\\Bill_\\Desktop\\Projetos\\EBAC\\DataScience\\Modolo 4\\acredaweb.csv', mode='r') as vac_acre:

url = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-e2c84c7f-fa9c-45af-a8f2-f113808eadb0.c000.csv'
df_acre = pd.read_csv(url, sep=';')

df_acre.head(n=2)
# Out:
# C:\Users\Bill_\AppData\Local\Temp\ipykernel_11244\4430249.py:3: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_acre = pd.read_csv(url, sep=';')
#                                  document_id  \
# 0  26958f5b-8c3e-475f-a804-7d41c669217e-i0b0
# 1  480b67b1-3d45-4a84-b55d-73e3255360d7-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  ef45a3bebd05f064b05dfc78c08d3f6cea8000b3481578...              21
# 1  d58579cf6de70c23c6da8516f117adcf84175475219754...              24
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1999-09-24                          F                        3
# 1              1997-02-06                          F                        4
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0                  PARDA                          120050.0
# ...

# %%
# 1) Sua solução aqui
df_acre.shape[0]
# Out:
# 346034

# %%
# 2) 
df_acre['paciente_id'].nunique()
# Out:
# 290264

# %%
# 3) 
df_acre['paciente_id'].loc[df_acre['vacina_descricao_dose'] == '1ª Dose'].nunique()
# Out:
# 139127

# %%
# 4) 
df_menor = df_acre[df_acre["paciente_idade"]<18]
df_menor['paciente_id'].nunique()

# %%
# 5)
df_acre['vacina_fabricante_nome'].nunique()
# Out:
# 12

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
df_menor = df_acre[df_acre["paciente_idade"]<18].copy()
df_menor.head()
# Out:
#                                   document_id  \
# 3   4850e70f-09ab-4876-9e2a-ed8a509b81c7-i0b0
# 4   904c8cd5-275a-48a9-806f-377491382508-i0b0
# 7   489f1d70-fc96-4891-b587-4939e51dc08e-i0b0
# 17  4929627a-7f3f-4fc1-a402-522d9d996fbd-i0b0
# 30  e5fc37b3-2e6e-4100-8d4c-68879f43eb4a-i0b0
#
#                                           paciente_id  paciente_idade  \
# 3   428d99f0ce8098a06abfe4ae9e9bf1714c998d7ce17955...              12
# 4   2350e3fb0f2f62cd5f3b458e4fd9ed847b78b5d0dd8dde...              17
# 7   e52b09ad944dc34e6a3fe24eafdd147a0224a6a5e9acd6...              16
# 17  71cabbf246ce46033e330eaff4f0ce73798f2949dbc96b...              15
# 30  8d4f909e1300a73124ca9603c3392a72fefa036b0469f8...              15
#
#    paciente_dataNascimento paciente_enumSexoBiologico  \
# 3               2009-08-17                          M
# 4               2004-01-06                          F
# 7               2005-05-24                          F
# ...

# %%
# 2) 
lista = df_menor.columns
lista
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# Faixa Etária                                      34022
# Outros                                             3701
# Povos Indígenas                                    1848
# Povos e Comunidades Tradicionais                    552
# Trabalhadores de Saúde                              238
# População Privada de Liberdade                       49
# Comorbidades                                         33
# Gestantes                                            23
# Pessoas com Deficiência                               3
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Trabalhadores da Educação                             1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4)
variaveis_estabelecimento = ['estabelecimento_valor', 'estabelecimento_razaoSocial', 
                             'estalecimento_noFantasia', 'estabelecimento_municipio_codigo',
                             'estabelecimento_municipio_nome', 'estabelecimento_uf']

colunas_estabelecimento = df_menor.loc[:,variaveis_estabelecimento]
colunas_estabelecimento
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 3                     6159087  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 4                     6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 7                     6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 17                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 30                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                       ...                                      ...
# 346003                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 346004                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 346020                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 346021                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 346025                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 5)
colunas_estabelecimento = colunas_estabelecimento.drop_duplicates()
colunas_estabelecimento
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 3                     6159087  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 4                     6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 48                    2002914  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 49                    2000962    PREFEITURA MUNICIPAL DE MANUEL URBANO
# 54                    2003066     PREFEITURA MUNICIPAL DE ASSIS BRASIL
# ...                       ...                                      ...
# 112666                2000091      PREFEITURA MUNICIPAL DE MANCIO LIMA
# 130769                2002884           PREFEITURA MUNICIPAL DE BUJARI
# 178165                7123043           PREFEITURA MUNICIPAL DE JORDAO
# 217881                9542566                PREFEITURA DE MANCIO LIMA
# 249740                7168748      PREFEITURA MUNICIPAL DE MANCIO LIMA
#
#                                  estalecimento_noFantasia  \
# ...
